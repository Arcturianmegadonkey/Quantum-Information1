# %%
pip install quiskit
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement quiskit (from versions: none)
# ERROR: No matching distribution found for quiskit

# %%
pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-1.2.4-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.15.1-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit) (2.1.1)
# Requirement already satisfied: scipy>=1.5 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit) (1.14.1)
# Collecting sympy>=1.3 (from qiskit)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3 (from qiskit)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit) (2.9.0.post0)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit) (4.11.0)
# Collecting symengine<0.14,>=0.11 (from qiskit)
#   Downloading symengine-0.13.0-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Collecting pbr>=2.0.0 (from stevedore>=3.0.0->qiskit)
#   Downloading pbr-6.1.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.3->qiskit)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading qiskit-1.2.4-cp38-abi3-win_amd64.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ------------------------- -------------- 2.9/4.6 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 13.8 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading rustworkx-0.15.1-cp38-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 11.2 MB/s eta 0:00:00
# Downloading stevedore-5.3.0-py3-none-any.whl (49 kB)
# Downloading symengine-0.13.0-cp312-cp312-win_amd64.whl (17.8 MB)
#    ---------------------------------------- 0.0/17.8 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/17.8 MB 15.4 MB/s eta 0:00:01
#    ------------- -------------------------- 6.0/17.8 MB 14.2 MB/s eta 0:00:01
#    -------------------- ------------------- 8.9/17.8 MB 14.6 MB/s eta 0:00:01
#    -------------------------- ------------- 11.8/17.8 MB 14.5 MB/s eta 0:00:01
#    --------------------------------- ------ 14.7/17.8 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.8 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 17.8/17.8 MB 13.4 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------------ --------------------- 2.9/6.2 MB 15.2 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 13.1 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 5.8 MB/s eta 0:00:00
# Downloading pbr-6.1.0-py2.py3-none-any.whl (108 kB)
# Installing collected packages: mpmath, sympy, symengine, rustworkx, pbr, dill, stevedore, qiskit
# Successfully installed dill-0.3.9 mpmath-1.3.0 pbr-6.1.0 qiskit-1.2.4 rustworkx-0.15.1 stevedore-5.3.0 symengine-0.13.0 sympy-1.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qiskit_aer
# Out:
# Collecting qiskit_aer
#   Downloading qiskit_aer-0.15.1-cp312-cp312-win_amd64.whl.metadata (8.2 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit_aer) (1.2.4)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit_aer) (2.1.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit_aer) (1.14.1)
# Requirement already satisfied: psutil>=5 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit_aer) (5.9.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (5.3.0)
# Requirement already satisfied: typing-extensions in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (4.11.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from qiskit>=1.1.0->qiskit_aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit_aer) (1.16.0)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_aer) (1.3.0)
# Downloading qiskit_aer-0.15.1-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.5 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\victo\anaconda3\envs\quantuminformation1\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/7.8 MB 13.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/7.8 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 12.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 12.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 13.3 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4

# %%
pip install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py): started
#   Building wheel for pylatexenc (setup.py): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136848 sha256=b9eed03547d0f8aa354c72b3ae481f8b1b40bbf53a4f7d62bea39d1c088be887
#   Stored in directory: c:\users\victo\appdata\local\pip\cache\wheels\06\3e\78\fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt 
from qiskit import * #qiskit
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex
#from qiskit.extensions import Initialize
from qiskit import QuantumCircuit, QuantumRegister, transpile, assemble#, execute, Aer, BasicAer
from qiskit_aer import Aer
from qiskit.quantum_info import random_statevector
from qiskit.quantum_info import partial_trace, entropy
import qiskit.quantum_info as qi

from IPython.display import HTML, display

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
n_qubit = 1
qr0 = QuantumRegister(n_qubit)
cr0 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc0 = QuantumCircuit(qr0,cr0) #quantum circuit with quantum and classical registers

qc0.draw('mpl')

# %%
qc0.measure(qr0,cr0)
shots = 1000
circuit0 = transpile(qc0, simulator)
job = simulator.run(circuit0, shots = shots)
result = job.result()
counts = result.get_counts(qc0)
plot_histogram(counts)

# %%
n_qubit = 5
qr1 = QuantumRegister(n_qubit)
cr1 = ClassicalRegister(n_qubit)
qc1 = QuantumCircuit(qr1, cr1)

qc1.h(qr1[0])
qc1.h(qr1[1])
qc1.h(qr1[2])
qc1.h(qr1[3])
qc1.h(qr1[4])
qc1.draw('mpl')

# %%
qc1.measure(qr1,cr1)
shots = 1000
circuit1 = transpile(qc1, simulator)
job = simulator.run(circuit1, shots = shots)
result = job.result()
counts = result.get_counts(qc1)
plot_histogram(counts)

# %%
qc1.measure(qr1,cr1)
shots = 10
circuit1 = transpile(qc1, simulator)
job = simulator.run(circuit1, shots = shots)
result = job.result()
counts = result.get_counts(qc1)
plot_histogram(counts)

# %%
qc1.measure(qr1,cr1)
shots = 100
circuit1 = transpile(qc1, simulator)
job = simulator.run(circuit1, shots = shots)
result = job.result()
counts = result.get_counts(qc1)
plot_histogram(counts)

# %%
qc1.measure(qr1,cr1)
shots = 1000
circuit1 = transpile(qc1, simulator)
job = simulator.run(circuit1, shots = shots)
result = job.result()
counts = result.get_counts(qc1)
plot_histogram(counts)

# %%
qc1.measure(qr1,cr1)
shots = 10000
circuit1 = transpile(qc1, simulator)
job = simulator.run(circuit1, shots = shots)
result = job.result()
counts = result.get_counts(qc1)
plot_histogram(counts)

# %%
from math import pi
n_qubit = 1
qr2 = QuantumRegister(n_qubit)
cr2 = ClassicalRegister(n_qubit)
qc2 = QuantumCircuit(qr2, cr2)

qc2.u(pi,pi/2,0,qr2)
qc2.draw()

qc2.draw('mpl')

# %%
n_qubit = 1
qr2 = QuantumRegister(n_qubit)
cr2 = ClassicalRegister(n_qubit)
qc2 = QuantumCircuit(qr2, cr2)

qc2.u(0, 3*pi/2,0,qr2)
qc2.draw()

qc2.draw('mpl')

# %%
n_qubit = 1
qr2 = QuantumRegister(n_qubit)
cr2 = ClassicalRegister(n_qubit)
qc2 = QuantumCircuit(qr2, cr2)

qc2.x(qr2[0])
qc2.h(qr2[0])
qc2.u(0,pi/2,0,qr2)

qc2.draw()
qc2.draw('mpl')

# %%
n_qubit = 2
qr3 = QuantumRegister(n_qubit)
cr3 = ClassicalRegister(n_qubit)
qc3 = QuantumCircuit(qr3, cr3)

qc3.draw('mpl')

# %%
import numpy as np
from numpy import array, dot, pi
import scipy.sparse as sp
from scipy.sparse.linalg import eigsh
from scipy.linalg import eigvals

# %%
Array = np.array([1,0,0,1])
Array2 = np.dot(np.sqrt(1/2),Array)
print(Array2)
# Out:
# [0.70710678 0.         0.         0.70710678]

# %%
n_qubit = 2
qr4 = QuantumRegister(n_qubit)
cr4 = ClassicalRegister(n_qubit)
qc4 = QuantumCircuit(qr4,cr4)
qc4.cx(qr4[0],qr4[1])

qc4.draw('mpl')

# %%
n_qubit = 2
qr5 = QuantumRegister(n_qubit)
cr5 = ClassicalRegister(n_qubit)
qc5 = QuantumCircuit(qr5,cr5)

qc5.h(qr5[0])
qc5.cx(qr5[0],qr5[1])

qc5.draw('mpl')

# %%
n_qubit = 2
qr3 = QuantumRegister(n_qubit)
cr3 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc3 = QuantumCircuit(qr3,cr3) #quantum circuit with quantum and classical registers

qc3.draw('mpl')

# %%
n_qubit = 2
qr3 = QuantumRegister(n_qubit)
cr3 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc3 = QuantumCircuit(qr3,cr3) #quantum circuit with quantum and classical registers

qc3.h(qr3[0])
qc3.draw('mpl')

# %%
import numpy as np
import matplotlib.pyplot as plt 
from qiskit import * #qiskit
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex
#from qiskit.extensions import Initialize
from qiskit import QuantumCircuit, QuantumRegister, transpile, assemble#, execute, Aer, BasicAer
from qiskit_aer import Aer
from qiskit.quantum_info import random_statevector
from qiskit.quantum_info import partial_trace, entropy
import qiskit.quantum_info as qi

from IPython.display import HTML, display

# %%
n_qubit = 2
qr4 = QuantumRegister(n_qubit)
cr4 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc4 = QuantumCircuit(qr4,cr4) #quantum circuit with quantum and classical registers

qc4.h(qr4[0])
qc4.cx(qr4[0],qr4[1])
qc4.draw('mpl')

# %%
n_qubit = 2
qr5 = QuantumRegister(n_qubit)
cr5 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc5 = QuantumCircuit(qr5,cr5) #quantum circuit with quantum and classical registers

qc5.h(qr5[1])
qc5.cx(qr5[0],qr5[1])

qc5.draw('mpl')

# %%
n_qubit = 2
qr6 = QuantumRegister(n_qubit)
cr6 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc6 = QuantumCircuit(qr6,cr6) #quantum circuit with quantum and classical registers

qc6.cx(qr6[0],qr6[1])
qc6.h(qr6[0])


qc6.draw('mpl')

# %%
n_qubit = 2
qr6 = QuantumRegister(n_qubit)
cr6 = ClassicalRegister(n_qubit) #classical register to store resulting bits
qc6 = QuantumCircuit(qr6,cr6) #quantum circuit with quantum and classical registers

qc6.cx(qr6[0],qr6[1])
qc6.h(qr6[1])


qc6.draw('mpl')
